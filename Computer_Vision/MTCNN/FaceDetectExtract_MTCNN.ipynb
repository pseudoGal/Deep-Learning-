# %% [markdown]
# FaceDetection and Extraction using MTCNN

# %%
# !pip install MTCNN

import matplotlib.pyplot as plt
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN

# %%
filename ="/content/img2.jpeg"
pixels = plt.imread(filename)
print("shape of array",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()
# Out:
# shape of array (1120, 840, 3)

# %%
# draw an image with detected objects
def draw_facebox(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height, fill=False, color='orange')
        # draw the box
        ax.add_patch(rect)
    # show the plot
    plt.show()
 

faces = detector.detect_faces(pixels)
# display faces on the original image
draw_facebox(filename, faces)

# %%
#/content/img4.jpeg

filename ="/content/Pratiksha_collage.jpeg"
pixels = plt.imread(filename)
print("shape of array",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()
# Out:
# shape of array (1280, 1024, 3)

# %%
# draw an image with detected objects
def draw_facebox(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height, fill=False, color='orange')
        # draw the box
        ax.add_patch(rect)
    # show the plot
    plt.show()
 
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_facebox(filename, faces)

# %%
#drwa an image with the detected objects

#/content/img4.jpeg

filename ="/content/saree_pratiksha.jpeg"
pixels = plt.imread(filename)
print("shape of array",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()
# Out:
# shape of array (1280, 853, 3)

# %%
# draw an image with detected objects
def draw_facebox(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height, fill=False, color='orange')
        # draw the box
        ax.add_patch(rect)
    # show the plot
    plt.show()
 
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_facebox(filename, faces)

# %%
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# {'box': [123, 821, 115, 150], 'confidence': 0.9999929666519165, 'keypoints': {'left_eye': (157, 876), 'right_eye': (211, 880), 'nose': (184, 910), 'mouth_left': (160, 935), 'mouth_right': (202, 938)}}
# {'box': [355, 442, 168, 223], 'confidence': 0.9999109506607056, 'keypoints': {'left_eye': (397, 532), 'right_eye': (476, 526), 'nose': (438, 579), 'mouth_left': (404, 609), 'mouth_right': (475, 606)}}
# {'box': [25, 169, 176, 235], 'confidence': 0.99967360496521, 'keypoints': {'left_eye': (69, 282), 'right_eye': (157, 273), 'nose': (118, 330), 'mouth_left': (81, 358), 'mouth_right': (158, 350)}}
# {'box': [659, 745, 129, 175], 'confidence': 0.998868465423584, 'keypoints': {'left_eye': (691, 815), 'right_eye': (755, 814), 'nose': (725, 858), 'mouth_left': (694, 875), 'mouth_right': (755, 875)}}
# ...

# %%
#draw an image with the detected objects

#/content/img4.jpeg

filename ="/content/img8.jpeg"
pixels = plt.imread(filename)
print("shape of array",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()
# Out:
# shape of array (1120, 840, 3)

# %%
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafcda75d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {'box': [273, 160, 347, 466], 'confidence': 0.9986781477928162, 'keypoints': {'left_eye': (377, 335), 'right_eye': (538, 382), 'nose': (430, 460), 'mouth_left': (339, 487), 'mouth_right': (477, 532)}}

# %%
# draw an image with detected objects
def draw_facebox(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height, fill=False, color='orange')
        # draw the box
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            
            dot = plt.Circle(value, radius=20, color='red')
            ax.add_patch(dot)

    # show the plot
    plt.show()
 
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_facebox(filename, faces)

# %%
#extract face
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN

def extract_face(filename, required_size=(224, 224)):
        pixels = pyplot.imread(filename)
        detector = MTCNN()
        results = detector.detect_faces(pixels)
        x1, y1, width, height = results[0]['box']
        x2, y2 = x1 + width, y1 + height
        #resize
        face = pixels[y1:y2, x1:x2]
        image = Image.fromarray(face)
        image = image.resize(required_size)
        face_array = asarray(image)
        return face_array

#pixels = extract_face("")
pixels = extract_face('/content/img8.jpeg')
# plot the extracted face
pyplot.imshow(pixels)
# show the plot
pyplot.show()

# %%
#extract face
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN

def extract_face(filename, required_size=(224, 224)):
        pixels = pyplot.imread(filename)
        detector = MTCNN()
        results = detector.detect_faces(pixels)
        x1, y1, width, height = results[2]['box']
        x2, y2 = x1 + width, y1 + height
        #resize
        face = pixels[y1:y2, x1:x2]
        image = Image.fromarray(face)
        image = image.resize(required_size)
        face_array = asarray(image)
        return face_array

#pixels = extract_face("")
pixels = extract_face('/content/saree_pratiksha.jpeg')
# plot the extracted face
pyplot.imshow(pixels)
# show the plot
pyplot.show()
